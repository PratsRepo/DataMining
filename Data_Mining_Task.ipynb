# %% [markdown]
# __Preamble__
#
# This dataset is concerned with insurance claims data from private health insurance. It is synthesized, but somewhat realistic.
#
# ____

# %% [markdown]
# ###  1: Import the file train.csv and show descriptive statistics for the dataset: What are the marginal distributions of the dependent features and the target variable ("Endkosten").

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("train.csv")
df
# Out:
#        Unnamed: 0         ID         Ereignisdatum            Meldedatum  \
# 0            6979  WC8607959  2003-12-31T14:00:00Z  2004-01-29T00:00:00Z
# 1           12975  WC7477367  2000-06-29T08:00:00Z  2000-10-29T00:00:00Z
# 2           19669  WC5586276  1996-10-14T10:00:00Z  1997-04-10T00:00:00Z
# 3           38404  WC9230570  2004-12-31T09:00:00Z  2005-01-10T00:00:00Z
# 4           45414  WC8670450  2003-02-27T10:00:00Z  2003-11-01T00:00:00Z
# ...           ...        ...                   ...                   ...
# 53995        4581  WC7625155  2000-08-10T11:00:00Z  2000-09-05T00:00:00Z
# 53996       26554  WC5749419  1996-07-01T08:00:00Z  1996-09-09T00:00:00Z
# 53997       42227  WC7828676  2001-10-26T16:00:00Z  2001-11-02T00:00:00Z
# 53998       22181  WC7104649  1999-11-20T12:00:00Z  1999-12-09T00:00:00Z
# 53999        7426  WC5878909  1997-12-05T12:00:00Z  1997-12-16T00:00:00Z
#
#        Alter Geschlecht Familienstand  Kinder  AndereHausstandsmitglieder  \
# 0         21          M             S       0                           0
# 1         16          M             S       0                           0
# 2         37          F             S       0                           0
# 3         44          M             S       0                           0
# 4         54          M             M       0                           0
# ...      ...        ...           ...     ...                         ...
# 53995     44          F             S       0                           0
# 53996     51          M             U       0                           0
# 53997     19          M             S       0                           0
# 53998     49          F             M       0                           0
# 53999     19          M             S       0                           0
#
#          LohnWoche Arbeitszeitkategorie  Arbeitszeitwoche  ArbeitstageWoche  \
# 0       909.351717                    P              20.0                 4
# 1       635.562035                    F              40.0                 5
# 2       791.829150                    F              38.0                 5
# 3       916.424284                    F              38.0                 5
# 4       928.223434                    F              38.0                 5
# ...            ...                  ...               ...               ...
# 53995   624.890314                    F              38.0                 5
# 53996   419.567395                    F              38.0                 5
# 53997  1153.913092                    F              80.0                 5
# 53998   409.865077                    F              40.0                 5
# 53999   827.434356                    F              48.0                 5
#
#                                      Schadenbeschreibung   Erstreserve  \
# 0                         STRUCK HAMMER BRUISED LEFT LEG   8436.167102
# 1         LADDER SLIPPED AND HIT ANKLE SPRAIN LEFT ANKLE   8372.177085
# 2      LIFTING PARCEL STRAIN NECK AND SHOULDERS NECK ...  12023.847580
# 3                        MOVING STRAIN LOWER BACK STRAIN  16373.536019
# 4                 PARTICLE IN EYE FOREIGN BODY RIGHT EYE   8510.012175
# ...                                                  ...           ...
# 53995  CAUGHT FINGER ON SLICING LACERATED LEFT INDEX ...   8467.306246
# 53996  LIFTING FILES STRAINED RIGHT FOREARM LEFT SHOU...  15637.524709
# 53997       LIFTING BOXES SOFT TISSUE INJURY LEFT FINGER  33208.039396
# 53998  SLICING MEATS RIGHT SHOULDER STRAIN RIGHT SHOU...   8679.542857
# 53999  STRUCK KNIFE LACERATED LEFT THUMB LACERATED THUMB  10166.487882
#
#           Endkosten
# 0          0.000000
# 1      14051.245443
# 2      72608.071751
# 3      63075.572628
# 4      87882.990895
# ...             ...
# 53995  11246.744272
# 53996  57329.074875
# 53997  35137.860624
# 53998  65834.700051
# 53999  11186.754782
#
# [54000 rows x 16 columns]

# %% [markdown]
# __Hint__: Use histograms, box and violin plots as well as a correlation matrix.

# %% [markdown]
# ### 2: The primary target variable is `Endkosten`. Build a regression model that estimates `Endkosten` from the dependent variables. Use the __root mean square measure__ to test the performance. Try to get close to $rmse < 1$.
#
# __Hint__: Standardize the numerical variables to $[-1,1]$ first and take the logarithmic transformation of the target variable.

# %% [markdown]
# ### 3: The insurance company's policy states that any claim above 25.000 is a "major claim". It would be very helpful to know in advance, judging from the initial claims report data (as obtained from train.csv), if a claim will be major. Train a classification model that differentiates between minor and major claims (from "Endkosten") with good accuracy (precision > 0.85). Ignore the description column "Schadenbeschreibung" for now.
#
# __Hint__: Make sure to split the dataset into training and test sets to check for overfitting. Pick a classifier that is robust to imbalanced datasets, as major claims are, by definition, rare.

# %% [markdown]
# ### 4: The company wants to test another approach that uses the hypothesis that only the 1% largest claims should be consired major claims. Train a new classifier that is based on the segmentation of claims into major claims based on the 99% threshold.
#
# __Hint__: Pay special attention to the imbalance of classes in the dataset.

# %% [markdown]
# ### 5: Improve your models from exercise 3/4 making use of the description column `Schadenbeschreibung`. A good model should give a score > 0.9, excellent models exhibit scores > 0.95.

# %% [markdown]
# __Hint__: Use data mining techniques that count, cluster and segment words. Start by making a word cloud and consider using a word-vector or a Latent Dirichlet Allocation method to generate improved input features.
